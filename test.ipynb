# %%
import pandas as pd

# %%
df = pd.read_json('data/clicks.json') 
df.head()
# Out:
#                                                 data
# 0  {'application_id': '4391677', 'publisher_name'...
# 1  {'application_id': '4391677', 'publisher_name'...
# 2  {'application_id': '4391677', 'publisher_name'...
# 3  {'application_id': '4391677', 'publisher_name'...
# 4  {'application_id': '4391677', 'publisher_name'...

# %%
df = pd.read_json('data/clicks.json') 
publisher_names = []
for row in df['data']:
    publisher_names.append(row['publisher_name'])

# %%
unique_publishers = set(publisher_names) 
print(unique_publishers)
# Out:
# {'Рефералки', 'SMM Korzinka Go', 'Охватка', 'Lebazar_old_app', 'Korzinka', 'Lebazar_media'}

# %%
tracker_names = []
for row in df['data']:
    tracker_names.append(row['tracker_name'])
unique_trackers = set(tracker_names) 
print(unique_trackers)
print(len(unique_trackers))
# Out:
# {'Korzinka_App_catalague', 'Для тг Корзинки и пуша в тг Корзинки на скачивание', 'Instagram', 'AdCollony', 'Korzinka_PR_link', 'Banner_link', 'Тест', 'ARIEL_авт.порошок "lenor effect" 3кг[20 каталог, хаммер]', 'Nescafe Gold 95гр с/б суб.[20 каталог, хаммер]', 'Telegram', 'Крем для рук Увлажнение и смягчение, Алое Вера и масло[22 каталог, топ10]', 'Диплинк для то Корзинки говядина', 'qr_пакеты', 'Жидкий порошок ABC для цветного 1500мл[18 каталог, хаммер]', 'Форель Радужная_GF (от 2кг до 3кг), вес[22 каталог, хаммер]', 'Шок.плитка Alpen Gold молочный 85г[21 каталог, топ10]', 'Lockscreen_app_link', 'МУКА пшеничная в/сорт 365 kun 2кг[22 каталог, хаммер]', 'Splat', 'qr_чеки', 'Яндекс_РТБ', 'Диплинк в категорию скидки в тг Корзинки', 'Именинникам промокод для PUSH Korzinka Core', 'Jacobs Gold с/б 95гр[18 каталог, хаммер]', 'Meta_CPM', 'Г.КОРЕЙКА,ВЕС[20 каталог, хаммер]', 'Яблоки Редчив Молдова, вес[22 каталог, топ10]', 'VALIO_Плав.сыр VIOLA сливочный 200гр[22 каталог, топ10]', 'Nescafe Gol
# ...

# %%
df_new = pd.read_csv('data/clicks_transformed.csv')
df_new.head()
# Out:
#    application_id publisher_name  publisher_id  \
# 0         4391677  Lebazar_media        141814
# 1         4391677       Korzinka        141586
# 2         4391677       Korzinka        141586
# 3         4391677       Korzinka        141586
# 4         4391677       Korzinka        141586
#
#                                         tracker_name         tracking_id  \
# 0                                          Instagram  100349058492664342
# 1                             Korzinka_App_catalague  172405533171578411
# 2                    Landing_Korzinka_Go_Google_play  388634754712399646
# 3  ARIEL_авт.порошок "lenor effect" 3кг[20 катало...  316679907482581999
# 4  SHERIN_Сосиски Егерские 700гр ± 20гр[22 катало...  316721727075796533
#
#    click_timestamp       click_datetime              click_ipv6  \
# 0       1698943515  2023-11-02 16:45:15    ::ffff:31.148.161.33
# 1       1698941333  2023-11-02 16:08:53  ::ffff:185.139.139.242
# ...

# %%
df_new.columns
# Out:
# Index(['application_id', 'publisher_name', 'publisher_id', 'tracker_name',
#        'tracking_id', 'click_timestamp', 'click_datetime', 'click_ipv6',
#        'click_url_parameters', 'click_id', 'click_user_agent', 'ios_ifa',
#        'ios_ifv', 'android_id', 'google_aid', 'device_manufacturer',
#        'device_model', 'is_bot', 'country_iso_code', 'city', 'click_date',
#        'click_time', 'os_name', 'os_version', 'browser', 'browser_version',
#        'device_type', 'publisher_category'],
#       dtype='object')
